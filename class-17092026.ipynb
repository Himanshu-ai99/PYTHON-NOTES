# %%
a = (10 , 20 , 30 , 40 ,60)
print(a)
# Out:
# (10, 20, 30, 40, 60)

# %%
b = (10)
print(b)
# Out:
# 10

# %%
print(type(a))
# Out:
# <class 'tuple'>

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
c = (10 , )
print(type(c))
# Out:
# <class 'tuple'>

# %%
d = tuple([ 1,2,3,4,5,6 ])
print(d)
print(type(d))
# Out:
# (1, 2, 3, 4, 5, 6)
# <class 'tuple'>

# %%
t = ()
print(type(t))
# Out:
# <class 'tuple'>

# %%
f = tuple("Python")
print(f)
print(type(f))
# Out:
# ('P', 'y', 't', 'h', 'o', 'n')
# <class 'tuple'>

# %%
g = ("Python","Java","C++","SQL")
print(g[0])
print(g[-1])
print(g[-3])
# Out:
# Python
# SQL
# Java

# %%
h = tuple([ 1,2,3,4,5,6 ])
del h
print(h)
print(h[0:4])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[23], line 3
#       1 h = tuple([ 1,2,3,4,5,6 ])
#       2 del h
# ----> 3 print(h)
#       4 print(h[0:4])
#
# NameError: name 'h' is not defined

# %%
print(h[0:])
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
print(h[:4])
# Out:
# (1, 2, 3, 4)

# %%
print(h[:])
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
i = (10,20,3,4,6,4,23,4)
print(i.count(4))
print(i.index(4))
# Out:
# 3
# 3
